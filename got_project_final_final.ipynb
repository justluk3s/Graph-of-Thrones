# %% [markdown]
# # Network of Thrones: hybrid RAG + knowledge graph assistant
#
# This notebook combines two complementary knowledge sources:
#
# - **Unstructured lore** (`lore.txt`): chunking → Sentence Transformer embeddings → FAISS dense index, combined with BM25 lexical retrieval.
# - **Structured facts** (`graph.trig`): RDF/SPARQL lookup through a dedicated tool.
# - **Grounded generation**: a local Ollama model chooses the appropriate tool and answers only from retrieved evidence.
#
# The retrieval stack is local. Model downloads require internet access only on the first run.

# %%
# Run once in a fresh Colab/Jupyter environment.
# %pip install -q langchain langchain-community langchain-ollama langgraph rdflib \
    sentence-transformers faiss-cpu rank_bm25 numpy pandas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 78.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.4/615.4 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 79.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 8.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %% [markdown]
# ## 1. Start the local language model
#
# The installation commands below target Google Colab/Linux. On Windows or macOS, install Ollama from https://ollama.com and start it before continuing.

# %%
# %system apt-get update -qq && apt-get install -y -qq zstd
# Out:
# ["W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)",
#  'Selecting previously unselected package zstd.',
#  '(Reading database ... ',
#  '(Reading database ... 5%',
#  '(Reading database ... 10%',
#  '(Reading database ... 15%',
#  '(Reading database ... 20%',
#  '(Reading database ... 25%',
#  '(Reading database ... 30%',
#  '(Reading database ... 35%',
#  '(Reading database ... 40%',
#  '(Reading database ... 45%',
#  '(Reading database ... 50%',
#  '(Reading database ... 55%',
#  '(Reading database ... 60%',
#  '(Reading database ... 65%',
#  '(Reading database ... 70%',
#  '(Reading database ... 75%',
#  '(Reading database ... 80%',
#  '(Reading database ... 85%',
#  '(Reading database ... 90%',
#  '(Reading database ... 95%',
#  '(Reading database ... 100%',
#  '(Reading database ... 122403 files and directories currently installed.)',
#  'Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...',
#  'Unpacking zstd (1.4.8+dfsg-3build1) ...',
#  'Setting up zstd (1.4.8+dfsg-3build1) ...',
#  'Processing triggers for man-db (2.10.2-1) ...']

# %%
# %system curl -fsSL https://ollama.com/install.sh | sh
# Out:
# ['>>> Installing ollama to /usr/local',
#  '>>> Downloading ollama-linux-amd64.tar.zst',
#  '#=#=#                                                                         ',
#  '##O#-#                                                                        ',
#  '##O=#  #                                                                      ',
#  '#=#=-#  #                                                                     ',
#  '',
#  '                                                                           0.3%',
#  '                                                                           0.8%',
#  '#                                                                          1.6%',
#  '#                                                                          2.7%',
#  '##                                                                         3.5%',
#  '###                                                                        4.2%',
#  '###                                                                        5.1%',
#  '####                                                                       6.1%',
#  '#####                                                                      7.1%',
#  '#####                                                                      7.9%',
#  '######                                                                     8.7%',
#  '######                                                                     8.8%',
#  '#######                                                                   10.4%',
#  '########                                                                  12.0%',
#  '#########                                                                 13.7%',
#  '##########                                                                15.1%',
#  '###########                                                               16.2%',
#  '############                                                              17.9%',
#  '#############                                                             19.4%',
#  '###############                                                           21.2%',
#  '################                                                          22.5%',
#  '#################                                                         24.3%',
#  '#################                                                         24.6%',
#  '#################                                                         24.9%',
#  '##################                                                        25.0%',
#  '##################                                                        25.7%',
#  '###################                                                       26.5%',
#  '###################                                                       27.0%',
#  '###################                                                       27.7%',
#  '####################                                                      28.6%',
#  '#####################                                                     29.3%',
#  '#####################                                                     30.2%',
#  '######################                                                    31.4%',
#  '#######################                                                   32.2%',
#  '########################                                                  33.5%',
#  '########################                                                  34.1%',
#  '#########################                                                 34.8%',
#  '#########################                                                 35.4%',
#  '#########################                                                 35.8%',
#  '##########################                                                36.4%',
#  '##########################                                                37.0%',
#  '###########################                                               38.1%',
#  '############################                                              39.2%',
#  '#############################                                             40.8%',
#  '##############################                                            41.8%',
#  '###############################                                           43.1%',
#  '###############################                                           43.9%',
#  '###############################                                           44.4%',
#  '################################                                          44.5%',
#  '################################                                          45.5%',
#  '#################################                                         46.1%',
#  '#################################                                         47.2%',
#  '##################################                                        48.3%',
#  '###################################                                       49.6%',
#  '####################################                                      51.0%',
#  '#####################################                                     52.5%',
#  '######################################                                    53.3%',
#  '######################################                                    54.0%',
#  '#######################################                                   54.9%',
#  '#######################################                                   55.5%',
#  '########################################                                  56.3%',
#  '#########################################                                 57.3%',
#  '##########################################                                58.4%',
#  '##########################################                                59.7%',
#  '###########################################                               60.9%',
#  '############################################                              62.4%',
#  '#############################################                             63.6%',
#  '##############################################                            64.3%',
#  '##############################################                            65.2%',
#  '###############################################                           66.6%',
#  '################################################                          67.8%',
#  '#################################################                         69.3%',
#  '##################################################                        70.5%',
#  '###################################################                       71.7%',
#  '####################################################                      73.3%',
#  '#####################################################                     74.9%',
#  '######################################################                    75.1%',
#  '######################################################                    75.3%',
#  '######################################################                    75.5%',
#  '######################################################                    75.8%',
#  '######################################################                    76.3%',
#  '#######################################################                   76.7%',
#  '#######################################################                   77.1%',
#  '#######################################################                   77.5%',
#  '########################################################                  78.9%',
#  '#########################################################                 80.1%',
#  '##########################################################                81.7%',
#  '###########################################################               83.0%',
#  '############################################################              84.3%',
#  '#############################################################             85.2%',
#  '##############################################################            86.6%',
#  '###############################################################           88.1%',
#  '################################################################          89.7%',
#  '#################################################################         90.9%',
#  '##################################################################        92.2%',
#  '##################################################################        92.6%',
#  '###################################################################       93.1%',
#  '###################################################################       94.2%',
#  '####################################################################      95.7%',
#  '######################################################################    97.3%',
#  '#######################################################################   98.8%',
#  '#######################################################################   99.3%',
#  '#######################################################################   99.7%',
#  '#######################################################################  100.0%',
#  '######################################################################## 100.0%',
#  '>>> Creating ollama user...',
#  '>>> Adding ollama user to video group...',
#  '>>> Adding current user to ollama group...',
#  '>>> Creating ollama systemd service...',
#  '\x1b\x1bWARNING:\x1b[m systemd is not running',
#  '\x1b\x1bWARNING:\x1b[m Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.',
#  '>>> The Ollama API is now available at 127.0.0.1:11434.',
#  '>>> Install complete. Run "ollama" from the command line.']

# %%
import platform
import shutil
import subprocess
import time
import requests

OLLAMA_MODEL = "mistral-nemo"

if shutil.which("ollama") is None:
    if platform.system() == "Linux":
        subprocess.run("curl -fsSL https://ollama.com/install.sh | sh", shell=True, check=True)
    else:
        raise RuntimeError("Install Ollama from https://ollama.com, then restart this notebook.")

def ensure_ollama_running():
    try:
        requests.get("http://localhost:11434/api/tags", timeout=2).raise_for_status()
        return
    except requests.RequestException:
        subprocess.Popen(
            ["ollama", "serve"],
            stdout=subprocess.DEVNULL,
            stderr=subprocess.DEVNULL,
        )
        time.sleep(5)

ensure_ollama_running()
subprocess.run(["ollama", "pull", OLLAMA_MODEL], check=True)
print(f"Ollama is ready with {OLLAMA_MODEL}.")
# Out:
# Ollama is ready with mistral-nemo.

# %% [markdown]
# ## 2. Load and chunk the lore corpus
#
# Overlapping chunks reduce the chance that a fact is split across chunk boundaries. Each chunk keeps metadata so retrieved evidence can be inspected and cited.

# %%
from pathlib import Path
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

LORE_PATH = Path("lore.txt")
GRAPH_PATH = Path("graph.trig")
CHUNK_SIZE = 500
CHUNK_OVERLAP = 75
TOP_K = 4

if not LORE_PATH.exists():
    raise FileNotFoundError("Upload lore.txt to the notebook working directory before continuing.")

source_docs = TextLoader(str(LORE_PATH), encoding="utf-8").load()
splitter = RecursiveCharacterTextSplitter(
    chunk_size=CHUNK_SIZE,
    chunk_overlap=CHUNK_OVERLAP,
    separators=["\n\n", "\n", ". ", " ", ""],
)
chunks = splitter.split_documents(source_docs)

for chunk_id, chunk in enumerate(chunks):
    chunk.metadata.update({"chunk_id": chunk_id, "source": LORE_PATH.name})

print({"source_documents": len(source_docs), "chunks": len(chunks)})
# Out:
# /tmp/ipykernel_583/2861717502.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# {'source_documents': 1, 'chunks': 739}

# %% [markdown]
# ## 3. Embed and index the chunks
#
# `all-MiniLM-L6-v2` maps both chunks and questions to normalized vectors. FAISS inner-product search then acts as cosine-similarity search. BM25 remains useful for exact names and rare terms, so the final retriever fuses both rankings with Reciprocal Rank Fusion (RRF).

# %%
import numpy as np
import pandas as pd
import faiss
from sentence_transformers import SentenceTransformer
from langchain_community.retrievers import BM25Retriever

EMBEDDING_MODEL = "sentence-transformers/all-MiniLM-L6-v2"
encoder = SentenceTransformer(EMBEDDING_MODEL)
chunk_texts = [chunk.page_content for chunk in chunks]

chunk_embeddings = encoder.encode(
    chunk_texts,
    normalize_embeddings=True,
    show_progress_bar=True,
)
chunk_embeddings = np.asarray(chunk_embeddings, dtype="float32")

dense_index = faiss.IndexFlatIP(chunk_embeddings.shape[1])
dense_index.add(chunk_embeddings)

bm25_retriever = BM25Retriever.from_documents(chunks)
bm25_retriever.k = min(12, len(chunks))

print({
    "embedding_model": EMBEDDING_MODEL,
    "embedding_dimension": chunk_embeddings.shape[1],
    "indexed_chunks": dense_index.ntotal,
})
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# {'embedding_model': 'sentence-transformers/all-MiniLM-L6-v2', 'embedding_dimension': 384, 'indexed_chunks': 739}

# %%
def dense_retrieve(query: str, candidate_k: int = 12):
    candidate_k = min(candidate_k, len(chunks))
    query_vector = encoder.encode(
        [query], normalize_embeddings=True, show_progress_bar=False
    ).astype("float32")
    scores, positions = dense_index.search(query_vector, candidate_k)
    return [
        {"chunk_id": int(position), "dense_score": float(score)}
        for score, position in zip(scores[0], positions[0])
        if position >= 0
    ]


def hybrid_retrieve(query: str, top_k: int = TOP_K, candidate_k: int = 12):
    '''Fuse semantic and lexical rankings with Reciprocal Rank Fusion.'''
    candidate_k = min(candidate_k, len(chunks))
    dense_hits = dense_retrieve(query, candidate_k)
    bm25_retriever.k = candidate_k
    lexical_docs = bm25_retriever.invoke(query)

    lexical_ids = [int(doc.metadata["chunk_id"]) for doc in lexical_docs]
    dense_scores = {hit["chunk_id"]: hit["dense_score"] for hit in dense_hits}
    fused = {}
    rrf_constant = 60

    for rank, hit in enumerate(dense_hits, start=1):
        fused[hit["chunk_id"]] = fused.get(hit["chunk_id"], 0.0) + 1 / (rrf_constant + rank)
    for rank, chunk_id in enumerate(lexical_ids, start=1):
        fused[chunk_id] = fused.get(chunk_id, 0.0) + 1 / (rrf_constant + rank)

    ranked_ids = sorted(fused, key=fused.get, reverse=True)[:top_k]
    return [
        {
            "rank": rank,
            "chunk_id": chunk_id,
            "rrf_score": fused[chunk_id],
            "dense_score": dense_scores.get(chunk_id),
            "source": chunks[chunk_id].metadata.get("source", LORE_PATH.name),
            "text": chunks[chunk_id].page_content,
        }
        for rank, chunk_id in enumerate(ranked_ids, start=1)
    ]


def retrieval_table(query: str, top_k: int = TOP_K):
    '''Human-readable retrieval diagnostics.'''
    return pd.DataFrame(hybrid_retrieve(query, top_k=top_k))[
        ["rank", "chunk_id", "rrf_score", "dense_score", "source", "text"]
    ]


retrieval_table("Who killed a member of House Stark?", top_k=3)
# Out:
#    rank  chunk_id  rrf_score  dense_score    source  \
# 0     1       666   0.030536     0.479221  lore.txt
# 1     2       356   0.016393     0.535155  lore.txt
# 2     3       224   0.016393          NaN  lore.txt
#
#                                                 text
# 0  Robb Stark, commonly known as The Young Wolf, ...
# 1  Rickard Stark is a male character.\nHe is from...
# 2  Jasper Waynwood is a male character.\nHe appea...

# %% [markdown]
# ## 4. Expose hybrid retrieval and the RDF graph as tools
#
# The lore tool returns evidence labels (`[lore:chunk_id]`) so the model can cite its sources. The graph tool is reserved for explicit relationships and other structured facts.

# %%
import re
import unicodedata

import rdflib
from rdflib import URIRef
from langchain_core.tools import tool


@tool
def search_lore(query: str) -> str:
    """Search biographies, narrative events, aliases, titles, culture and appearances."""
    hits = hybrid_retrieve(query, top_k=TOP_K)

    if not hits:
        return "No relevant lore was found."

    return "\n\n".join(
        f"[lore:{hit['chunk_id']}] {hit['text']}"
        for hit in hits
    )


rdf_dataset = None

if GRAPH_PATH.exists():
    rdf_dataset = rdflib.Dataset(default_union=True)
    rdf_dataset.parse(str(GRAPH_PATH), format="trig")


def normalize_text(text: str) -> str:
    text = unicodedata.normalize("NFKC", text)
    text = (
        text.replace("’", "'")
        .replace("‘", "'")
        .replace("â€™", "'")
        .replace("â€˜", "'")
    )
    return " ".join(text.casefold().split())

def display_name(term) -> str:
    return (
        str(term)
        .rsplit("/", 1)[-1]
        .rsplit("#", 1)[-1]
        .replace("_", " ")
    )


# Index characters appearing as subjects or objects.
character_index = {}

if rdf_dataset is not None:
    for subject, _, obj in rdf_dataset.triples((None, None, None)):
        for entity in (subject, obj):
            if not isinstance(entity, URIRef):
                continue

            name = display_name(entity)
            character_index[normalize_text(name)] = name


def character_from_question(question: str) -> str | None:
    normalized_question = normalize_text(question)

    # Match longer names before shorter names.
    candidates = sorted(
        character_index.items(),
        key=lambda item: len(item[0]),
        reverse=True,
    )

    for normalized_name, display in candidates:
        if re.search(
            rf"\b{re.escape(normalized_name)}\b",
            normalized_question,
        ):
            return display

    return None


# How an incoming relation should be expressed from the selected character's perspective.
INVERSE_RELATIONS = {
    "killed": "killedBy",
    "killedBy": "killed",
    "childOf": "parentOf",
    "parentOf": "childOf",
    "siblingOf": "siblingOf",
    "serves": "servedBy",
    "servedBy": "serves",
    "guardedBy": "guardianOf",
    "guardianOf": "guardedBy",
    "marriedOrEngagedTo": "marriedOrEngagedTo",
}


@tool
def query_graph_db(character_name: str) -> str:
    """
    Return all incoming and outgoing relationships for one character.

    Pass only the character name, for example "Daenerys Targaryen".
    """
    if rdf_dataset is None:
        return "No structured data found."

    normalized_character = normalize_text(character_name)
    rows = []

    for subject, predicate, obj in rdf_dataset.triples((None, None, None)):
        subject_name = display_name(subject)
        object_name = display_name(obj)
        relation = display_name(predicate)

        # Outgoing relation: selected character is the subject.
        if normalize_text(subject_name) == normalized_character:
            rows.append(f"{relation}: {object_name}")

        # Incoming relation: selected character is the object.
        if normalize_text(object_name) == normalized_character:
            inverse = INVERSE_RELATIONS.get(
                relation,
                f"incoming_{relation}",
            )
            rows.append(f"{inverse}: {subject_name}")

    rows = sorted(set(rows))

    if not rows:
        return f"No structured data found for {character_name}."

    return "\n".join(rows)


print("Hybrid lore and RDF graph tools are ready.")
# Out:
# Hybrid lore and RDF graph tools are ready.

# %% [markdown]
# ## 5. Grounded local agent
#
# The prompt separates retrieval policy from answer formatting. It also instructs the agent to cite evidence labels and to abstain when the available sources are insufficient.

# %%
import re
from langchain.agents import create_agent
from langchain_ollama import ChatOllama
from langchain_core.messages import ToolMessage
from pydantic import BaseModel, Field


class ListAnswer(BaseModel):
    items: list[str] = Field(
        default_factory=list,
        description=(
            "Only atomic values directly requested by the question and explicitly "
            "present in the evidence. No explanations, Markdown or tool names."
        ),
    )


class SentenceAnswer(BaseModel):
    sentence: str = Field(
        default="",
        description=(
            "One factual sentence of at most 30 words that directly answers the "
            "descriptive question using only supplied evidence."
        ),
    )


llm = ChatOllama(model=OLLAMA_MODEL, temperature=0)

retrieval_prompt = """
You are a retrieval agent for a Game of Thrones database.

For every factual Game of Thrones question, decide whether to call "search_lore", "query_graph_db" or both. Never answer from pretrained knowledge!

Retrieval policy to follow:
- For descriptive questions such as "Who is X?", call both tools.
- Use "search_lore" for biographies, aliases, titles, culture and appearances.
- Use "query_graph_db" for kills, family, service, marriage and guardianship.
- Use both tools when both structured and unstructured evidence may help.
- Make no more than five calls to each tool.

Your prose answer is discarded. Retrieve the evidence required by the user question.
"""

retrieval_agent = create_agent(
    model=llm,
    tools=[search_lore, query_graph_db],
    system_prompt=retrieval_prompt,
)

list_formatter = ChatOllama(
    model=OLLAMA_MODEL, temperature=0
).with_structured_output(ListAnswer, method="json_schema")

sentence_formatter = ChatOllama(
    model=OLLAMA_MODEL, temperature=0
).with_structured_output(SentenceAnswer, method="json_schema")

print("The assistant is ready.")
# Out:
# The assistant is ready.

# %%
import re

from langchain_core.messages import ToolMessage


NO_DATA_MARKERS = (
    "no relevant lore was found",
    "no structured data found",
    "graph.trig is unavailable",
)

LORE_REQUEST_PATTERN = re.compile(
    r"\b("
    r"alias|aliases|title|titles|culture|born|birth|birthplace|"
    r"died|death|actor|actress|played|portrayed|book|books|"
    r"season|seasons|appearance|appearances|biography|background|description"
    r")\b",
    flags=re.IGNORECASE,
)

RELATION_PATTERNS = [
    (r"^(who|which\s+characters?)\s+(serve|serves|served)\b", "servedBy"),
    (r"\bserved by\b", "servedBy"),
    (r"^(who|whom)\s+does\s+.+?\s+serve\b", "serves"),
    (r"^who\s+killed\b", "killedBy"),
    (r"\b(killed by|killer|killers)\b", "killedBy"),
    (r"^(who|whom)\s+did\s+.+?\s+kill\b", "killed"),
    (r"\b(victim|victims)\b", "killed"),
    (r"\b(parent|parents|mother|father)\b", "childOf"),
    (r"\b(child|children|son|sons|daughter|daughters)\b", "parentOf"),
    (r"\b(sibling|siblings|brother|brothers|sister|sisters)\b", "siblingOf"),
    (r"^(who|which\s+characters?)\s+(guard|guards|guarded)\b", "guardedBy"),
    (r"\bguarded by\b", "guardedBy"),
    (r"\bguardian of\b", "guardianOf"),
    (r"\b(married|marriage|engaged|spouse|husband|wife)\b", "marriedOrEngagedTo"),
]


def requested_relations(question: str) -> list[str]:
    normalized = normalize_text(question)
    relations = []
    for pattern, relation in RELATION_PATTERNS:
        if re.search(pattern, normalized) and relation not in relations:
            relations.append(relation)
    return relations


def requests_lore_information(question: str) -> bool:
    return bool(LORE_REQUEST_PATTERN.search(normalize_text(question)))


def extract_relation_values(graph_evidence: str, expected_relation: str) -> list[str]:
    values = []
    for line in graph_evidence.splitlines():
        line = line.strip().lstrip("-").strip()
        if ":" not in line:
            continue
        relation, value = line.split(":", 1)
        value = value.strip()
        if relation.strip() == expected_relation and value and value not in values:
            values.append(value)
    return values


def is_descriptive_question(question: str) -> bool:
    return bool(re.match(r"^(who|what)\s+(is|was)\b", normalize_text(question)))


def valid_evidence(content: str) -> bool:
    normalized = content.strip().lower()
    return bool(normalized) and not any(marker in normalized for marker in NO_DATA_MARKERS)


def ask_assistant(user_query: str) -> str:
    relations = requested_relations(user_query)
    character_name = character_from_question(user_query)
    needs_lore = requests_lore_information(user_query)
    descriptive = is_descriptive_question(user_query)

    graph_values = []
    evidence_parts = []

    # Retrieve every requested structured relation once.
    if relations and character_name is not None:
        graph_evidence = query_graph_db.invoke({"character_name": character_name})
        if valid_evidence(graph_evidence):
            evidence_parts.append(graph_evidence)
            for relation in relations:
                for value in extract_relation_values(graph_evidence, relation):
                    if value not in graph_values:
                        graph_values.append(value)

    # A pure graph question is complete here. A composite question must continue.
    if relations and not needs_lore and not descriptive:
        return ", ".join(graph_values) if graph_values else "No entity found in the database."

    # Explicit lore request: call lore retrieval directly so it cannot be skipped by the agent.
    if needs_lore:
        lore_evidence = search_lore.invoke({"query": user_query})
        if valid_evidence(lore_evidence):
            evidence_parts.append(lore_evidence)
    else:
        retrieval_result = retrieval_agent.invoke(
            {"messages": [{"role": "user", "content": user_query}]},
            config={"recursion_limit": 15},
        )
        for message in retrieval_result["messages"]:
            if isinstance(message, ToolMessage):
                content = str(message.content).strip()
                if valid_evidence(content) and content not in evidence_parts:
                    evidence_parts.append(content)

    if not evidence_parts:
        return ", ".join(graph_values) if graph_values else "No entity found in the database."

    evidence = "\n\n".join(evidence_parts)

    # Only a simple profile question becomes a sentence.
    if descriptive and not relations and not needs_lore:
        answer = sentence_formatter.invoke(
            f"""
Write one direct factual sentence of at most 30 words using only the evidence.
Do not mention the tools called.

Question:
{user_query}

Evidence:
{evidence}
"""
        )
        sentence = answer.sentence.strip()
        return sentence if sentence else "No entity found in the database."

    # Lore-only or graph+lore composite question: extract all requested values.
    answer = list_formatter.invoke(
        f"""
Return all atomic values requested by every part of the question.

Rules:
- Use only the supplied evidence.
- Answer every part joined by words such as "and" or "also".
- Include all requested aliases, titles, names, relationships, appearances,
  cultures or dates present in the evidence.
- Do not return explanations, Markdown, tool names.
- Do not repeat values already listed under Graph values.
- Return an empty items list only if the evidence contains no additional values.

Question:
{user_query}

Graph values:
{graph_values}

Evidence:
{evidence}
"""
    )

    combined_values = list(graph_values)
    for item in answer.items:
        item = item.strip()
        if item and item not in combined_values:
            combined_values.append(item)

    return ", ".join(combined_values) if combined_values else "No entity found in the database."

# %% [markdown]
# ## 7. Ask questions
#
# This loop streams agent events, shows which knowledge source is consulted, and prints the final grounded answer.

# %%
print("Welcome to the Network of Thrones Assistant. Type 'exit' or 'quit' to stop.")

while True:
    user_input = input("\nUser: ").strip()

    if not user_input:
        continue

    if user_input.lower() in {"exit", "quit"}:
        print("System shutting down. Valar Morghulis!")
        break

    try:
        print(f"\nAssistant: {ask_assistant(user_input)}")
    except Exception as error:
        print(f"Request failed: {error}")
# Out:
# Welcome to the Network of Thrones Assistant. Type 'exit' or 'quit' to stop.
#
# User: Who are Jon Snow’s parents, and what aliases and titles does the lore assign to him?
#
# Assistant: Lyanna Stark, Rhaegar Targaryen, Lord Snow, Ned Stark's Bastard, The Snow of Winterfell, The Crow-Come-Over, The 998th Lord Commander of the Night's Watch, The Bastard of Winterfell, The Black Bastard of the Wall, Lord Crow
#
# User: who is jon snow?>
#
# Assistant: Jon Snow, born in 283 AC, is a male character from Northmen culture who serves as Lord Commander of the Night's Watch.
#
# User: Who are Jon Snow’s parents?
#
# Assistant: Lyanna Stark, Rhaegar Targaryen
#
# User: Who are Arya Stark’s parents and siblings?
#
# Assistant: Catelyn Stark, Eddard Stark, Bran Stark, Rickon Stark, Robb Stark, Sansa Stark
#
# User: Which characters have multiple aliases but no recorded actor?
#
# Assistant: Skahaz mo Kandaq, Skahaz Shavepate, Skinner, Skittrick, Sky Blue Su, Skyte, Val, Lady Val, Varamyr, Varamyr Sixskins, Haggon, Lump
#
# User: What titles did Tyrion Lannister hold, and where was he born?
#
# Assistant: Acting Hand of the King, Master of Coin, Casterly Rock
#
# User: Which characters appear in every listed television season from 1 to 6?
#
# Assistant: Kit Harington, Miltos Yeromelou, Patrick Malahide
#
# User: What aliases, titles, culture, and birthplace are recorded for Daenerys Targaryen?
#
# Assistant: Dany, Daenerys Stormborn, The Unburnt, Mother of Dragons, Mother, Mhysa, The Silver Queen, Silver Lady, Dragonmother, The Dragon Queen, The Mad King's daughter, Valyrian culture, 284 AC
#
# User: Which characters serve Daenerys Targaryen?
#
# Assistant: Barristan Selmy, Daario Naharis, Grey Worm, Jorah Mormont, Missandei, Tyrion Lannister
#
# User: exit
# System shutting down. Valar Morghulis!

# %% [markdown]
# __________________

# %% [markdown]
# ## 6. Retrieval evaluation
#
# Evaluate retrieval separately from generation. Add representative questions and the IDs of chunks that you judge relevant after inspecting `retrieval_table`. Recall@k and reciprocal rank expose whether failures come from retrieval rather than generation.

# %%
def evaluate_retrieval(test_cases, k=TOP_K):
    rows = []
    for case in test_cases:
        hits = hybrid_retrieve(case["query"], top_k=k)
        retrieved_ids = [hit["chunk_id"] for hit in hits]
        relevant = set(case["relevant_chunk_ids"])
        relevant_ranks = [
            rank for rank, chunk_id in enumerate(retrieved_ids, start=1)
            if chunk_id in relevant
        ]
        rows.append({
            "query": case["query"],
            "retrieved_chunk_ids": retrieved_ids,
            f"recall@{k}": len(relevant.intersection(retrieved_ids)) / len(relevant) if relevant else 0.0,
            "reciprocal_rank": 1 / min(relevant_ranks) if relevant_ranks else 0.0,
        })
    return pd.DataFrame(rows)


# Replace these examples with validated chunk IDs from your own lore.txt.
evaluation_cases = [
    {"query": "Who is Jon Snow?", "relevant_chunk_ids": [574]},
]

if evaluation_cases:
    display(evaluate_retrieval(evaluation_cases))
else:
    print("Add labelled evaluation_cases after inspecting retrieval_table(query).")
